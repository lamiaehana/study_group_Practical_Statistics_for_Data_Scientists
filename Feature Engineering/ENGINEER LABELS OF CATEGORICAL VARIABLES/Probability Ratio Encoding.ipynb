# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Replacing labels by joint probability of the target being 1 or 0

# %% [markdown]
# for each label, we calculate the mean of target=1, that is the probability of beign 1 (P(1)), and also the probability of the target=0 (P(O)). and then, we calculate the ratio P(1)/P(0), and replace the labels by the ratio

# %%
import pandas as pd

from sklearn.model_selection import train_test_split

# %matplotlib inline

# %%
data = pd.read_csv("/content/drive/MyDrive/Feature Engineering/titanic_train.csv", usecols=['Cabin', 'Survived'])
data.head()
# Out:
#    Survived   Cabin
# 0         1  C12239
# 1         0     NaN
# 2         0     NaN
# 3         0     NaN
# 4         1     NaN

# %%
# fill Na values with an additional label 

data.Cabin.fillna('Missing', inplace=True)
data.head()
# Out:
#    Survived    Cabin
# 0         1   C12239
# 1         0  Missing
# 2         0  Missing
# 3         0  Missing
# 4         1  Missing

# %%
len(data.Cabin.unique())
# Out:
# 26993

# %%
data['Cabin'] =  data['Cabin'].astype(str).str[0]
data.head()
# Out:
#    Survived Cabin
# 0         1     C
# 1         0     M
# 2         0     M
# 3         0     M
# 4         1     M

# %%
data.Cabin.unique()
# Out:
# array(['C', 'M', 'A', 'D', 'B', 'E', 'F', 'G', 'T'], dtype=object)

# %%
X_train, X_test, y_train, y_test = train_test_split(data[['Cabin', 'Survived']], data.Survived, test_size=0.3, random_state=0)

X_train.shape, X_test.shape
# Out:
# ((70000, 2), (30000, 2))

# %%
X_train.groupby(['Cabin'])['Survived'].mean()
# Out:
# Cabin
# A    0.273529
# B    0.627943
# C    0.709877
# D    0.733488
# E    0.612613
# F    0.830769
# G    0.860606
# M    0.341836
# T    0.520000
# Name: Survived, dtype: float64

# %%
prob_df = X_train.groupby(['Cabin'])['Survived'].mean()
prob_df = pd.DataFrame(prob_df)
prob_df
# Out:
#        Survived
# Cabin
# A      0.273529
# B      0.627943
# C      0.709877
# D      0.733488
# E      0.612613
# F      0.830769
# G      0.860606
# M      0.341836
# T      0.520000

# %%
prob_df = X_train.groupby(['Cabin'])['Survived'].mean()
prob_df = pd.DataFrame(prob_df)
prob_df['Died'] = 1 - prob_df.Survived
prob_df
# Out:
#        Survived      Died
# Cabin
# A      0.273529  0.726471
# B      0.627943  0.372057
# C      0.709877  0.290123
# D      0.733488  0.266512
# E      0.612613  0.387387
# F      0.830769  0.169231
# G      0.860606  0.139394
# M      0.341836  0.658164
# T      0.520000  0.480000

# %%
prob_df['ratio'] = prob_df.Survived/prob_df.Died
prob_df
# Out:
#        Survived      Died     ratio
# Cabin
# A      0.273529  0.726471  0.376518
# B      0.627943  0.372057  1.687757
# C      0.709877  0.290123  2.446809
# D      0.733488  0.266512  2.752174
# E      0.612613  0.387387  1.581395
# F      0.830769  0.169231  4.909091
# G      0.860606  0.139394  6.173913
# M      0.341836  0.658164  0.519379
# T      0.520000  0.480000  1.083333

# %%
# make a dictionary with the above ratio
prob_df['ratio'].to_dict()
# Out:
# {'A': 0.37651821862348184,
#  'B': 1.6877572016460909,
#  'C': 2.446808510638298,
#  'D': 2.7521739130434786,
#  'E': 1.581395348837209,
#  'F': 4.909090909090911,
#  'G': 6.173913043478261,
#  'M': 0.519379100656105,
#  'T': 1.0833333333333335}

# %%
ordered_labels = prob_df['ratio'].to_dict()

# %%
## replace the labels with the ordred numbers 
X_train['Cabin_ordered'] = X_train.Cabin.map(ordered_labels)
X_test['Cabin_ordered'] = X_test.Cabin.map(ordered_labels)

# %%
X_train.head()
# Out:
#       Cabin  Survived  Cabin_ordered
# 42865     M         0       0.519379
# 91446     M         0       0.519379
# 66374     M         0       0.519379
# 79106     C         0       2.446809
# 13404     M         1       0.519379
